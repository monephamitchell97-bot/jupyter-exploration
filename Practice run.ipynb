# %% [markdown]
# <a href="https://colab.research.google.com/github/monephamitchell97-bot/jupyter-exploration/blob/main/Practice%20run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
